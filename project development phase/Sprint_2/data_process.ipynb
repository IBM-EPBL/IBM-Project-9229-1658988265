# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Loading Dataset

# %%
data = pd.read_csv('Global.csv')

# %% [markdown]
# data

# %%
data
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
data.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data.info()
# Out:
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_11348\2441300724.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Order Date'] = pd.to_datetime(data['Order Date'])
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
# ...

# %%
a = data.groupby(['Order Date', 'Profit'])
a.first()
# Out:
#                      Row ID         Order ID   Ship Date       Ship Mode  \
# Order Date Profit
# 2011-01-01 -26.055    11731  IT-2011-3647632  05-01-2011    Second Class
#             15.342    22254    IN-2011-47883  08-01-2011  Standard Class
#             29.640    48883     HU-2011-1220  05-01-2011    Second Class
#             36.036    22253    IN-2011-47883  08-01-2011  Standard Class
#             37.770    22255    IN-2011-47883  08-01-2011  Standard Class
# ...                     ...              ...         ...             ...
# 2014-12-31  166.440   42474     OD-2014-9490  05-01-2015  Standard Class
#             180.240   15297  ES-2014-5281275  04-01-2015    Second Class
#             216.720   15693  ES-2014-1695428  02-01-2015    Second Class
#             251.400   12929  ES-2014-3458802  05-01-2015  Standard Class
#             301.466    1783   MX-2014-116267  03-01-2015    Second Class
#
# ...

# %% [markdown]
# understanding unique data

# %%
data.nunique()
# Out:
# Row ID            51290
# Order ID          25035
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID        1590
# Customer Name       795
# Segment               3
# City               3636
# State              1094
# Country             147
# Postal Code         631
# Market                7
# Region               13
# Product ID        10292
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             22995
# Quantity             14
# Discount             27
# Profit            24575
# Shipping Cost     10037
# Order Priority        4
# dtype: int64

# %%
height = data.iloc[:,3:4]
data['Ship Mode'] = data['Ship Mode'].astype('category')
data['Segment'] = data['Segment'].astype('category')
data['Country'] = data['Country'].astype('category')
data['Market'] = data['Market'].astype('category')
data['Region'] = data['Region'].astype('category')
data['Category'] = data['Category'].astype('category')
data['Sub-Category'] = data['Sub-Category'].astype('category')
data['Order Priority'] = data['Order Priority'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  category
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  category
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  category
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  category
#  13  Region          51290 non-null  category
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  category
# ...

# %% [markdown]
# cleaning

# %%
def remove_leading_spaces(data):
    for cols in data.columns:
        if data[cols].dtypes in ['object','category']:
            data[cols] = data[cols].str.strip()
        return data
data = remove_leading_spaces(data)
data.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298  CA-2012-124891 2012-07-31  31-07-2012      Same Day    RH-19495
# 1   26341   IN-2013-77878 2013-05-02  07-02-2013  Second Class    JR-16210
# 2   25330   IN-2013-71249 2013-10-17  18-10-2013   First Class    CR-12730
#
#    Customer Name    Segment           City            State  ...  \
# 0    Rick Hansen   Consumer  New York City         New York  ...
# 1  Justin Ritter  Corporate     Wollongong  New South Wales  ...
# 2   Craig Reiter   Consumer       Brisbane       Queensland  ...
#
#         Product ID    Category Sub-Category  \
# 0  TEC-AC-10003033  Technology  Accessories
# 1  FUR-CH-10003950   Furniture       Chairs
# 2  TEC-PH-10004664  Technology       Phones
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# ...

# %% [markdown]
# country

# %%
data.groupby(['Country']).count()[['Order ID']]
# Out:
#              Order ID
# Country
# Afghanistan        55
# Albania            16
# Algeria           196
# Angola            122
# Argentina         390
# ...               ...
# Venezuela         194
# Vietnam           265
# Yemen              30
# Zambia            102
# Zimbabwe           80
#
# [147 rows x 1 columns]

# %%
city

# %%
data.groupby(['City']).count()[['Order ID']]
# Out:
#                        Order ID
# City
# Aachen                       17
# Aalen                         1
# Aalst                         4
# Aba                          25
# Abadan                       11
# ...                         ...
# Zwedru                        1
# Zwickau                       3
# Zwolle                        2
# eMbalenhle                    2
# Águas Lindas de Goiás         4
#
# [3636 rows x 1 columns]

# %% [markdown]
# top 10 countries

# %%
top10 = data.groupby(['Country']).sum()[['Quantity']].nlargest(n=10, columns=['Quantity'])
top10
# Out:
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_11348\2762013751.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top10 = data.groupby(['Country']).sum()[['Quantity']].nlargest(n=10, columns=['Quantity'])
#                 Quantity
# Country
# United States      37873
# France             10804
# Australia          10673
# Mexico             10011
# Germany             7745
# China               7081
# United Kingdom      6161
# Brazil              6148
# India               5758
# Indonesia           5237

# %% [markdown]
# top5 countries on profit

# %%
top5 = data.groupby(['Country']).sum()[['Quantity']].nlargest(n=5, columns=['Quantity'])
data2 = data.groupby(['Product Name']).sum()[['Profit']].nlargest(n=5, columns=['Profit'])
data2
# Out:
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_11348\4039892467.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top5 = data.groupby(['Country']).sum()[['Quantity']].nlargest(n=5, columns=['Quantity'])
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_11348\4039892467.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2 = data.groupby(['Product Name']).sum()[['Profit']].nlargest(n=5, columns=['Profit'])
#                                            Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier  25199.9280
# Cisco Smart Phone, Full Size           17238.5206
# ...

# %%
data.groupby(['Product Name']).sum()[['Profit']].sort_values(by="Profit",ascending=False).nlargest(n=5, columns=['Profit']).plot.bar()
# Out:
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_11348\940556394.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Product Name']).sum()[['Profit']].sort_values(by="Profit",ascending=False).nlargest(n=5, columns=['Profit']).plot.bar()
# <AxesSubplot: xlabel='Product Name'>

# %%
data.groupby(['Country']).sum()[['Profit']].sort_values(by="Profit",ascending=False).nlargest(n=5, columns=['Profit']).plot.bar(color="green")
plt.show()
# Out:
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_11348\2787597950.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Country']).sum()[['Profit']].sort_values(by="Profit",ascending=False).nlargest(n=5, columns=['Profit']).plot.bar(color="green")

# %%
data.groupby(['Product Name']).count()[['Order ID']].nlargest(n=5, columns=['Order ID'])
# Out:
#                                 Order ID
# Product Name
# Staples                              227
# Cardinal Index Tab, Clear             92
# Eldon File Cart, Single Width         90
# Rogers File Cart, Single Width        84
# Ibico Index Tab, Clear                83

# %%
data.groupby(['City']).count()[['Order ID']].sort_values(by="Order ID",ascending=True).nlargest(n=10, columns=['Order ID']).plot.barh(color='navy')
plt.show()

# %%
data.groupby(['Category']).count()[['Order ID']].sort_values(by="Order ID",ascending=False).nlargest(n=5, columns=['Order ID']).plot.pie(subplots=True)
plt.show()

# %%
data.groupby(['Category']).sum()[['Profit']].sort_values(by="Profit",ascending=False).nlargest(n=5, columns=['Profit']).plot.pie(subplots=True)
plt.show()
# Out:
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_11348\3554681103.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Category']).sum()[['Profit']].sort_values(by="Profit",ascending=False).nlargest(n=5, columns=['Profit']).plot.pie(subplots=True)
